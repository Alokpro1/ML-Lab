# %%
import math
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(-5000,5000,500)
y=np.linspace(-5000,5000,500)

# %%
stdx=np.std(x)
stdy=np.std(y)
mx=2500
my=3800

# %%
def gaussian(p,x,y):
    r=np.exp(-(((x-mx)/stdx)**2-2*p*((x-mx)/stdx)*((y-mx)/stdy)+((y-mx)/stdy)**2)/(2*(1-p*p)))
    data_y=r/(2*3.14*stdx*stdy*math.sqrt(1-p*p))

    return data_y

# %%
def plt_plot_pdf(x, y, z):
  fig = plt.figure(figsize=(12, 6))
  ax = fig.gca(projection='3d')
  ax.plot_surface(x, y, z, 
                  cmap=cm.coolwarm,
                  linewidth=0, 
                  antialiased=True)
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  ax.set_zlabel('z');
  plt.show()

# %%
X, Y = np.meshgrid(x, y)
data=gaussian(0.1,X,Y)

# %%
plt_plot_pdf(X,Y,data)
